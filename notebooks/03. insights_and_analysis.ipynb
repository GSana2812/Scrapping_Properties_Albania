# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from src.preparation import Analysis

# %%
# load data
df = pd.read_csv('../data/data_real_estate_cleaned.csv')

Analysis.general_info(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2648 entries, 0 to 2647
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Gross Area     2648 non-null   float64
#  1   Interior Area  2648 non-null   float64
#  2   Bedrooms       2648 non-null   float64
#  3   Baths          2648 non-null   float64
#  4   Floor          2648 non-null   float64
#  5   Type           2648 non-null   object
#  6   Status         2648 non-null   object
#  7   Price          2648 non-null   float64
#  8   City           2648 non-null   object
# dtypes: float64(6), object(3)
# memory usage: 186.3+ KB
# None
#    Gross Area  Interior Area  Bedrooms  Baths  Floor        Type  \
# 0       96.78          96.78       2.0    2.0    5.0    Parking
# 1       86.00          68.00       2.0    2.0    5.0  Apartment
# 2      197.00         157.00       2.0    2.0    5.0  Apartment
# ...

# %%
Analysis.histograms(df, cols=['Gross Area', 'Interior Area', 'Price'])
